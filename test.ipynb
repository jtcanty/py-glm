# %% [markdown]
# First, we will simulate a data-set of discrete reponse variables with a Poisson error distribution.

# %%
plt.scatter(x,y)
plt.show()

# %%
)

# %%
# Simulate data with a
# Out:
# (100,)
